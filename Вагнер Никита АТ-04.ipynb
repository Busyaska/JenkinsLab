# %% [markdown]
# GitHub: https://github.com/Busyaska/JenkinsLab

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h4>Команды запуска:</h4>
# <ol>
# 	<li>
# 		<b>Download</b>
# 		<ul>
# 			<pre>
# 			D:\Programming\python\python.exe -m venv venv
# 			call venv\Scripts\activate
# 			venv\Scripts\python.exe -m pip install --upgrade pip
# 			venv\Scripts\python.exe -m pip install -r requirements.txt
# 			venv\Scripts\python.exe download.py
# 			</pre>
# 		</ul>
# 	</li>
# 		<li>
# 		<b>Train</b>
# 		<ul>
# 			<pre>
# 			cd
# 			cd download
# 			call venv\Scripts\activate
# 			venv\Scripts\python.exe train.py
# 			</pre>
# 		</ul>
# 	</li>
# 		<li>
# 		<b>Deploy</b>
# 		<ul>
# 			<pre>
# 			cd
# 			cd download
# 			call venv\Scripts\activate
# 			set BUILD_ID=dontKillMe
# 			set JENKINS_NODE_COOKIE=dontKillMe
# 			for /f "delims=" %%i in (best_model_path.txt) do set path_model=%%i
# 			start /b mlflow models serve -m %path_model% -p 5003 --no-conda
# 			</pre>
# 		</ul>
# 	</li>
# 		<li>
# 		<b>Test</b>
# 		<ul>
# 			<pre>
# 			cd ..
# 			cd download
# 			call venv\Scripts\activate
# 			venv\Scripts\python.exe test.py
# 			</pre>
# 		</ul>
# 	</li>
# </ol>

# %% [markdown]
# <h4>Pipeline Script</h4>
# <pre>
# pipeline {
# 	agent any
# 	stages {
# 		stage('Download') {
# 			steps {
# 				build job: "download"
# 			}
# 		}
# 		stage ('Train') {
# 			steps {
# 				build job: "train"
# 				}
# 			}
# 		stage ('Deploy') {
# 			steps {
# 				build job: 'deploy'
# 			}
# 		}
# 		stage ('Test') {
# 			steps {
# 				build job: 'test'
# 			}
# 		}
# 	}
# }
# </pre>

# %% [markdown]
# <h4>Pipeline logs</h4>
# <pre>
# Started by user admin
#
# [Pipeline] Start of Pipeline
# [Pipeline] node
# Running on Jenkins
#  in C:\ProgramData\Jenkins\.jenkins\workspace\pipeline
# [Pipeline] {
# [Pipeline] stage
# [Pipeline] { (Download)
# [Pipeline] build (Building download)
# Scheduling project: download
#
# Starting building: download #12
#
# Build download #12
#  completed: SUCCESS
# [Pipeline] }
# [Pipeline] // stage
# [Pipeline] stage
# [Pipeline] { (Train)
# [Pipeline] build (Building train)
# Scheduling project: train
#
# Starting building: train #3
#
# Build train #3
#  completed: SUCCESS
# [Pipeline] }
# [Pipeline] // stage
# [Pipeline] stage
# [Pipeline] { (Deploy)
# [Pipeline] build (Building deploy)
# Scheduling project: deploy
#
# Starting building: deploy #2
#
# Build deploy #2
#  completed: SUCCESS
# [Pipeline] }
# [Pipeline] // stage
# [Pipeline] stage
# [Pipeline] { (Test)
# [Pipeline] build (Building test)
# Scheduling project: test
#
# Starting building: test #2
#
# Build test #2
#  completed: SUCCESS
# [Pipeline] }
# [Pipeline] // stage
# [Pipeline] }
# [Pipeline] // node
# [Pipeline] End of Pipeline
# Finished: SUCCESS
# </pre>

# %% [markdown]
# <h4>Download logs</h4>
# <pre>
# Started by upstream project "pipeline
# " build number 2
#
# originally caused by:
#  Started by user admin
#
# Running as SYSTEM
# Building in workspace C:\ProgramData\Jenkins\.jenkins\workspace\download
# The recommended git tool is: NONE
# using credential 20aa35cd-99cb-48f9-b1e2-3a6c939d5468
#  > git.exe rev-parse --resolve-git-dir C:\ProgramData\Jenkins\.jenkins\workspace\download\.git # timeout=10
# Fetching changes from the remote Git repository
#  > git.exe config remote.origin.url https://github.com/Busyaska/JenkinsLab # timeout=10
# Fetching upstream changes from https://github.com/Busyaska/JenkinsLab
#  > git.exe --version # timeout=10
#  > git --version # 'git version 2.47.0.windows.2'
# using GIT_SSH to set credentials
# Verifying host key using known hosts file
# You're using 'Known hosts file' strategy to verify ssh host keys, but your known_hosts file does not exist, please go to 'Manage Jenkins' -> 'Security' -> 'Git Host Key Verification Configuration' and configure host key verification.
#  > git.exe fetch --tags --force --progress -- https://github.com/Busyaska/JenkinsLab +refs/heads/*:refs/remotes/origin/* # timeout=10
#  > git.exe rev-parse "refs/remotes/origin/main^{commit}" # timeout=10
# Checking out Revision c52077969f1dae8692870ffb0c5f1b32e137a300 (refs/remotes/origin/main)
#  > git.exe config core.sparsecheckout # timeout=10
#  > git.exe checkout -f c52077969f1dae8692870ffb0c5f1b32e137a300 # timeout=10
# Commit message: "chage commands format"
#  > git.exe rev-list --no-walk c52077969f1dae8692870ffb0c5f1b32e137a300 # timeout=10
# [download] $ cmd /c call C:\Windows\TEMP\jenkins3175439669316668571.bat
#
# C:\ProgramData\Jenkins\.jenkins\workspace\download>D:\Programming\python\python.exe -m venv venv
# Unable to copy 'D:\\Programming\\python\\Lib\\venv\\scripts\\nt\\venvlauncher.exe' to 'C:\\ProgramData\\Jenkins\\.jenkins\\workspace\\download\\venv\\Scripts\\python.exe'
#
# C:\ProgramData\Jenkins\.jenkins\workspace\download>call venv\Scripts\activate
# Requirement already satisfied: pip in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (25.0.1)
# Requirement already satisfied: alembic==1.15.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 1)) (1.15.2)
# Requirement already satisfied: annotated-types==0.7.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: anyio==4.9.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: asttokens==3.0.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: blinker==1.9.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: cachetools==5.5.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: certifi==2025.1.31 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 7)) (2025.1.31)
# Requirement already satisfied: charset-normalizer==3.4.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 8)) (3.4.1)
# Requirement already satisfied: click==8.1.8 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 9)) (8.1.8)
# Requirement already satisfied: cloudpickle==3.1.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 10)) (3.1.1)
# Requirement already satisfied: colorama==0.4.6 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: cycler==0.12.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: databricks-sdk==0.49.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 15)) (0.49.0)
# Requirement already satisfied: debugpy==1.8.13 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 16)) (1.8.13)
# Requirement already satisfied: decorator==5.2.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 17)) (5.2.1)
# Requirement already satisfied: Deprecated==1.2.18 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 18)) (1.2.18)
# Requirement already satisfied: docker==7.1.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 19)) (7.1.0)
# Requirement already satisfied: executing==2.2.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 20)) (2.2.0)
# Requirement already satisfied: fastapi==0.115.12 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 21)) (0.115.12)
# Requirement already satisfied: Flask==3.1.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 22)) (3.1.0)
# Requirement already satisfied: fonttools==4.56.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 23)) (4.56.0)
# Requirement already satisfied: gitdb==4.0.12 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 24)) (4.0.12)
# Requirement already satisfied: GitPython==3.1.44 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 25)) (3.1.44)
# Requirement already satisfied: google-auth==2.38.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 26)) (2.38.0)
# Requirement already satisfied: graphene==3.4.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 27)) (3.4.3)
# Requirement already satisfied: graphql-core==3.2.6 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 28)) (3.2.6)
# Requirement already satisfied: graphql-relay==3.2.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 29)) (3.2.0)
# Requirement already satisfied: greenlet==3.1.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 30)) (3.1.1)
# Requirement already satisfied: h11==0.14.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: idna==3.10 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 32)) (3.10)
# Requirement already satisfied: importlib_metadata==8.6.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 33)) (8.6.1)
# Requirement already satisfied: ipykernel==6.29.5 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 34)) (6.29.5)
# Requirement already satisfied: ipython==9.0.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 35)) (9.0.2)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 36)) (1.1.1)
# Requirement already satisfied: itsdangerous==2.2.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 37)) (2.2.0)
# Requirement already satisfied: jedi==0.19.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 38)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 39)) (3.1.6)
# Requirement already satisfied: joblib==1.4.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 40)) (1.4.2)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 41)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 42)) (5.7.2)
# Requirement already satisfied: kagglehub==0.3.10 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 43)) (0.3.10)
# Requirement already satisfied: kiwisolver==1.4.8 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 44)) (1.4.8)
# Requirement already satisfied: Mako==1.3.9 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 45)) (1.3.9)
# Requirement already satisfied: Markdown==3.7 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 46)) (3.7)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 47)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 48)) (3.10.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 49)) (0.1.7)
# Requirement already satisfied: mlflow==2.21.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 50)) (2.21.2)
# Requirement already satisfied: mlflow-skinny==2.21.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 51)) (2.21.2)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 52)) (1.6.0)
# Requirement already satisfied: numpy==2.2.4 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 53)) (2.2.4)
# Requirement already satisfied: opentelemetry-api==1.31.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 54)) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk==1.31.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 55)) (1.31.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 56)) (0.52b1)
# Requirement already satisfied: packaging==24.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 57)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 58)) (2.2.3)
# Requirement already satisfied: parso==0.8.4 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 59)) (0.8.4)
# Requirement already satisfied: pillow==11.1.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 60)) (11.1.0)
# Requirement already satisfied: platformdirs==4.3.7 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 61)) (4.3.7)
# Requirement already satisfied: prompt_toolkit==3.0.50 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 62)) (3.0.50)
# Requirement already satisfied: protobuf==5.29.4 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 63)) (5.29.4)
# Requirement already satisfied: psutil==7.0.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 64)) (7.0.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 65)) (0.2.3)
# Requirement already satisfied: pyarrow==19.0.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 66)) (19.0.1)
# Requirement already satisfied: pyasn1==0.6.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 67)) (0.6.1)
# Requirement already satisfied: pyasn1_modules==0.4.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 68)) (0.4.2)
# Requirement already satisfied: pydantic==2.11.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 69)) (2.11.1)
# Requirement already satisfied: pydantic_core==2.33.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 70)) (2.33.0)
# Requirement already satisfied: Pygments==2.19.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 71)) (2.19.1)
# Requirement already satisfied: pyparsing==3.2.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 72)) (3.2.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 73)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 74)) (2025.2)
# Requirement already satisfied: pywin32==310 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 75)) (310)
# Requirement already satisfied: PyYAML==6.0.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 76)) (6.0.2)
# Requirement already satisfied: pyzmq==26.3.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 77)) (26.3.0)
# Requirement already satisfied: requests==2.32.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 78)) (2.32.3)
# Requirement already satisfied: rsa==4.9 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 79)) (4.9)
# Requirement already satisfied: scikit-learn==1.6.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 80)) (1.6.1)
# Requirement already satisfied: scipy==1.15.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 81)) (1.15.2)
# Requirement already satisfied: six==1.17.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 82)) (1.17.0)
# Requirement already satisfied: smmap==5.0.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 83)) (5.0.2)
# Requirement already satisfied: sniffio==1.3.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 84)) (1.3.1)
# Requirement already satisfied: SQLAlchemy==2.0.40 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 85)) (2.0.40)
# Requirement already satisfied: sqlparse==0.5.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 86)) (0.5.3)
# Requirement already satisfied: stack-data==0.6.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 87)) (0.6.3)
# Requirement already satisfied: starlette==0.46.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 88)) (0.46.1)
# Requirement already satisfied: threadpoolctl==3.6.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 89)) (3.6.0)
# Requirement already satisfied: tornado==6.4.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 90)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 91)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 92)) (5.14.3)
# Requirement already satisfied: typing-inspection==0.4.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 93)) (0.4.0)
# Requirement already satisfied: typing_extensions==4.13.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 94)) (4.13.0)
# Requirement already satisfied: tzdata==2025.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 95)) (2025.2)
# Requirement already satisfied: urllib3==2.3.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 96)) (2.3.0)
# Requirement already satisfied: uvicorn==0.34.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 97)) (0.34.0)
# Requirement already satisfied: waitress==3.0.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 98)) (3.0.2)
# Requirement already satisfied: wcwidth==0.2.13 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 99)) (0.2.13)
# Requirement already satisfied: Werkzeug==3.1.3 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 100)) (3.1.3)
# Requirement already satisfied: wrapt==1.17.2 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 101)) (1.17.2)
# Requirement already satisfied: zipp==3.21.0 in c:\programdata\jenkins\.jenkins\workspace\download\venv\lib\site-packages (from -r requirements.txt (line 102)) (3.21.0)
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (0.3.11).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/natezhang123/social-anxiety-dataset?dataset_version_number=2...
#
#   0%|          | 0.00/403k [00:00<?, ?B/s]
# 100%|##########| 403k/403k [00:00<00:00, 875kB/s]
# 100%|##########| 403k/403k [00:00<00:00, 874kB/s]
# Extracting files...
# Finished: SUCCESS
#
# </pre>

# %% [markdown]
# <h4>Train logs</h4>
# <pre>
# Started by upstream project "pipeline
# " build number 2
#
# originally caused by:
#  Started by user admin
#
# Running as SYSTEM
# Building in workspace C:\ProgramData\Jenkins\.jenkins\workspace\train
# [train] $ cmd /c call C:\Windows\TEMP\jenkins8757605288121841653.bat
#
# C:\ProgramData\Jenkins\.jenkins\workspace\train>cd ..
#
# C:\ProgramData\Jenkins\.jenkins\workspace>cd download
#
# C:\ProgramData\Jenkins\.jenkins\workspace\download>call venv\Scripts\activate
# C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Finished: SUCCESS
#
# </pre>

# %% [markdown]
# <h4>Deploy logs</h4>
# <pre>
# Started by upstream project "pipeline
# " build number 2
#
# originally caused by:
#  Started by user admin
#
# Running as SYSTEM
# Building in workspace C:\ProgramData\Jenkins\.jenkins\workspace\deploy
# [deploy] $ cmd /c call C:\Windows\TEMP\jenkins8979767737150888295.bat
#
# C:\ProgramData\Jenkins\.jenkins\workspace\deploy>cd ..
#
# C:\ProgramData\Jenkins\.jenkins\workspace>cd download
#
# C:\ProgramData\Jenkins\.jenkins\workspace\download>call venv\Scripts\activate
#
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading artifacts:  20%|##        | 1/5 [00:00<00:00, 23431.87it/s]
# Downloading artifacts:  40%|####      | 2/5 [00:00<00:00, 18893.26it/s]
# Downloading artifacts:  60%|######    | 3/5 [00:00<00:00, 19508.39it/s]
# Downloading artifacts:  80%|########  | 4/5 [00:00<00:00, 20971.52it/s]
# Downloading artifacts: 100%|##########| 5/5 [00:00<00:00, 21936.74it/s]
# Downloading artifacts: 100%|##########| 5/5 [00:00<00:00, 17623.13it/s]
# 2025/04/03 16:37:37 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
# 2025/04/03 16:37:37 INFO mlflow.pyfunc.backend: === Running command 'uvicorn --host 127.0.0.1 --port 5003 --workers 1 mlflow.pyfunc.scoring_server.app:app'
# INFO:     Started server process [17620]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 10048] error while attempting to bind on address ('127.0.0.1', 5003): [winerror 10048] ������ ����������� ������ ���� ������������� ������ ������ (��������/������� �����/����)
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Scripts\mlflow.exe\__main__.py", line 7, in <module>
#     sys.exit(cli())
#              ~~~^^
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\click\core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\click\core.py", line 1082, in main
#     rv = self.invoke(ctx)
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\click\core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\click\core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\click\core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\click\core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\mlflow\models\cli.py", line 104, in serve
#     ).serve(
#       ~~~~~^
#         model_uri=model_uri, port=port, host=host, timeout=timeout, enable_mlserver=enable_mlserver
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\ProgramData\Jenkins\.jenkins\workspace\download\venv\Lib\site-packages\mlflow\pyfunc\backend.py", line 322, in serve
#     raise Exception(
#         f"Command '{command}' returned non zero return code. Return code = {rc}"
#     )
# Exception: Command 'uvicorn --host 127.0.0.1 --port 5003 --workers 1 mlflow.pyfunc.scoring_server.app:app' returned non zero return code. Return code = 1
# Finished: SUCCESS
#
# </pre>

# %% [markdown]
# <h4>Test logs</h4>
# <pre>
# Started by upstream project "pipeline
# " build number 2
#
# originally caused by:
#  Started by user admin
#
# Running as SYSTEM
# Building in workspace C:\ProgramData\Jenkins\.jenkins\workspace\test
# [test] $ cmd /c call C:\Windows\TEMP\jenkins17145600679682804940.bat
#
# C:\ProgramData\Jenkins\.jenkins\workspace\test>cd ..
#
# C:\ProgramData\Jenkins\.jenkins\workspace>cd download
#
# C:\ProgramData\Jenkins\.jenkins\workspace\download>call venv\Scripts\activate
# Response: {'predictions': [0.0911966391493223]}
# Finished: SUCCESS
#
# </pre>
